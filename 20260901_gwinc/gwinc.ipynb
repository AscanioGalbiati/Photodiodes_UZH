# %%
import gwinc
budget = gwinc.load_budget('aLIGO')
trace = budget.run()
fig = trace.plot()
fig.show()
# Out:
# /var/folders/z2/x35ff22s25jgptbssk4ctryc0000gn/T/ipykernel_80567/2835546988.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
